# %%
#!pip install scikit-surprise

# %% [markdown]
# documentation of the Surprise package can be found at http://surprise.readthedocs.io/en/stable/index.html

# %%
from surprise import Dataset
from surprise import evaluate, print_perf
from surprise import Reader
from surprise import KNNBasic

# %%
import os
data_file_path = "ratings.dat"
data_file_path
# Out:
# 'ratings.dat'

# %%
# As we're loading a custom dataset, we need to define a reader. In the
# course talk data set that we are using, each line has the following format:
# 'user item rating', separated by '|' characters.

"""
The Reader class is used to parse a file containing ratings.

Such a file is assumed to specify only one rating per line, and each line needs to respect the following structure:

user ; item ; rating ; [timestamp]

Here we dont have time stamp and it is optional

"""
reader_object = Reader(line_format='user item rating', sep='|',rating_scale=(1, 5), skip_lines=0)
data = Dataset.load_from_file(data_file_path, reader=reader_object)

# %%
# We need to split the Data into five folds to perform cross validation
data.split(n_folds=5)

# %%
# We'll use the famous User Based Collaborative Filtering algorithm.there are a list of other algorithms that can be used in the Surprise package
similarity_params = {'name': 'cosine',
               'user_based': True  # compute  similarities between users
               }
algo = KNNBasic(sim_options=similarity_params)

# Evaluate performances of our algorithm on the dataset.
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])

print_perf(perf)
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic.
#
# ------------
# C:\ProgramData\Anaconda3\envs\tf_keras\lib\site-packages\surprise\prediction_algorithms\algo_base.py:231: RuntimeWarning: invalid value encountered in double_scalars
#   sim = construction_func[name](*args)
# Fold 1
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9741
# MAE:  0.6772
# ------------
# Fold 2
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9411
# MAE:  0.6489
# ------------
# Fold 3
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9512
# MAE:  0.6702
# ------------
# Fold 4
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.9592
# MAE:  0.6516
# ------------
# Fold 5
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0105
# MAE:  0.6738
# ------------
# ------------
# Mean RMSE: 0.9672
# Mean MAE : 0.6643
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean
# MAE     0.6772  0.6489  0.6702  0.6516  0.6738  0.6643
# RMSE    0.9741  0.9411  0.9512  0.9592  1.0105  0.9672

# %% [markdown]
# # Grid Search
#
# In the context of machine learning, hyperparameters are parameters whose values are set prior to the commencement of the learning process. By contrast, the value of other parameters is derived via training.Hyperparameter optimization or model selection is the problem of choosing a set of optimal hyperparameters for a learning algorithm, for optimizing a measure of the algorithm's performance on a data set.
#
# The traditional way of performing hyperparameter optimization has been grid search, or a parameter sweep, which is simply an exhaustive searching through a manually specified subset of the hyperparameter space of a learning algorithm. A grid search algorithm must be guided by some performance metric, typically measured by cross-validation on the training set or evaluation on a held-out validation set.
# Grid search suffers from the curse of high dimentionality. Since it has to search for every possible combination of specified hyper parameter. SO grid serach must be used wisely

# %%
from surprise import GridSearch
param_grid = {'min_k': [1,2,3,4,5], 'k': [35,36,37,38,39,40]}
grid_search = GridSearch(KNNBasic, param_grid, measures=['RMSE', 'MAE'])
grid_search.evaluate(data)
# Out:
# ------------
# Parameters combination 1 of 30
# params:  {'min_k': 1, 'k': 35}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 2 of 30
# params:  {'min_k': 1, 'k': 36}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 3 of 30
# params:  {'min_k': 1, 'k': 37}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 4 of 30
# params:  {'min_k': 1, 'k': 38}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 5 of 30
# params:  {'min_k': 1, 'k': 39}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 6 of 30
# params:  {'min_k': 1, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9656
# Mean FCP : 0.5363
# ------------
# ------------
# Parameters combination 7 of 30
# params:  {'min_k': 2, 'k': 35}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 8 of 30
# params:  {'min_k': 2, 'k': 36}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 9 of 30
# params:  {'min_k': 2, 'k': 37}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 10 of 30
# params:  {'min_k': 2, 'k': 38}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 11 of 30
# params:  {'min_k': 2, 'k': 39}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 12 of 30
# params:  {'min_k': 2, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9491
# Mean FCP : 0.5302
# ------------
# ------------
# Parameters combination 13 of 30
# params:  {'min_k': 3, 'k': 35}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 14 of 30
# params:  {'min_k': 3, 'k': 36}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 15 of 30
# params:  {'min_k': 3, 'k': 37}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 16 of 30
# params:  {'min_k': 3, 'k': 38}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 17 of 30
# params:  {'min_k': 3, 'k': 39}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 18 of 30
# params:  {'min_k': 3, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9409
# Mean FCP : 0.5094
# ------------
# ------------
# Parameters combination 19 of 30
# params:  {'min_k': 4, 'k': 35}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 20 of 30
# params:  {'min_k': 4, 'k': 36}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 21 of 30
# params:  {'min_k': 4, 'k': 37}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 22 of 30
# params:  {'min_k': 4, 'k': 38}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 23 of 30
# params:  {'min_k': 4, 'k': 39}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 24 of 30
# params:  {'min_k': 4, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9442
# Mean FCP : 0.4871
# ------------
# ------------
# Parameters combination 25 of 30
# params:  {'min_k': 5, 'k': 35}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------
# ------------
# Parameters combination 26 of 30
# params:  {'min_k': 5, 'k': 36}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------
# ------------
# Parameters combination 27 of 30
# params:  {'min_k': 5, 'k': 37}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------
# ------------
# Parameters combination 28 of 30
# params:  {'min_k': 5, 'k': 38}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------
# ------------
# Parameters combination 29 of 30
# params:  {'min_k': 5, 'k': 39}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------
# ------------
# Parameters combination 30 of 30
# params:  {'min_k': 5, 'k': 40}
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# ------------
# Mean RMSE: 0.9457
# Mean FCP : 0.4670
# ------------

# %%
# To know results of grid search

# best RMSE score in the model
print("Best RMSE Score is:{!r}".format(grid_search.best_score['RMSE']))


# combination of parameters that gave the best RMSE score
print("Parameter to achieve Best RMSE Score is:{!r}".format(grid_search.best_params['RMSE']))


# best MAE score
print("Best MAE Score is :{!r}".format(grid_search.best_score['MAE']))


# combination of parameters that gave the best MAE score
print("Parameter to achieve Best MAE Score is:{!r}".format(grid_search.best_params['MAE']))
# Out:
# Best RMSE Score is:0.94089109969450635
# Parameter to achieve Best RMSE Score is:{'min_k': 3, 'k': 35}
# Best FCP Score is :0.53630313019054188
# Parameter to achieve Best RMSE Score is:{'min_k': 1, 'k': 35}

# %%
#converting all results of grid search into a pandas table for better understanding
import pandas as pd
results_df = pd.DataFrame.from_dict(grid_search.cv_results)
results_df.head()
# Out:
#         FCP      RMSE   k  min_k                 params  \
# 0  0.536303  0.965589  35      1  {'min_k': 1, 'k': 35}
# 1  0.536303  0.965589  36      1  {'min_k': 1, 'k': 36}
# 2  0.536303  0.965589  37      1  {'min_k': 1, 'k': 37}
# 3  0.536303  0.965589  38      1  {'min_k': 1, 'k': 38}
# 4  0.536303  0.965589  39      1  {'min_k': 1, 'k': 39}
#
#                                             scores
# 0  {'RMSE': 0.965589004571, 'FCP': 0.536303130191}
# 1  {'RMSE': 0.965589004571, 'FCP': 0.536303130191}
# 2  {'RMSE': 0.965589004571, 'FCP': 0.536303130191}
# 3  {'RMSE': 0.965589004571, 'FCP': 0.536303130191}
# 4  {'RMSE': 0.965589004571, 'FCP': 0.536303130191}
